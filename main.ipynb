# %% [markdown]
# <a href="https://colab.research.google.com/github/YuAon/Fundamentals_Analysis/blob/main/main.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !cat /etc/issue
# Out:
# Ubuntu 18.04.5 LTS \n \l

# %%
# !python3 --version
# Out:
# Python 3.7.10

# %%
# !pip list
# Out:
# Package                       Version
# ----------------------------- -------------------
# absl-py                       0.12.0
# alabaster                     0.7.12
# albumentations                0.1.12
# altair                        4.1.0
# appdirs                       1.4.4
# argon2-cffi                   20.1.0
# arviz                         0.11.2
# astor                         0.8.1
# astropy                       4.2.1
# astunparse                    1.6.3
# async-generator               1.10
# atari-py                      0.2.9
# atomicwrites                  1.4.0
# attrs                         21.2.0
# audioread                     2.1.9
# autograd                      1.3
# Babel                         2.9.1
# backcall                      0.2.0
# beautifulsoup4                4.6.3
# bleach                        3.3.0
# blis                          0.4.1
# bokeh                         2.3.2
# Bottleneck                    1.3.2
# ...

# %%
import warnings
warnings.simplefilter('ignore')

# %%
# !pip install lightgbm==2.2.3
# !pip install ta==0.7.0
# Out:
# ...
#   Created wheel for ta: filename=ta-0.7.0-cp37-none-any.whl size=28716 sha256=834dcaa895a0386569968ec3c4f33ba4f47f3f51ef5b561ab19e683942618746
#   Stored in directory: /root/.cache/pip/wheels/dd/88/30/de9553fb54a474eb7480b937cdbb140bdda613d29cf4da7994
# Successfully built ta
# ...

# %%
# google driveをマウントしてdataフォルダを指定
DATASET_DIR= "/content/drive/MyDrive/signate/SIGNATE_fundamentals_analysis/data"

# %%
# %cd /content/drive/MyDrive/signate/SIGNATE_fundamentals_analysis/src/
# Out:
# /content/drive/MyDrive/signate/SIGNATE_fundamentals_analysis/src

# %%
from predictor import ScoringService
inputs = ScoringService.get_inputs(DATASET_DIR)

# %%
# %%time
# 学習&モデル保存

# 保存したい場所を指定
model_path = "/content/drive/MyDrive/signate/SIGNATE_fundamentals_analysis/model"
ScoringService.train_and_save_model(inputs, model_path=model_path)
# Out:
# label_high_20
# ...
# [1]	train's spearman: 0.312617	eval's spearman: 0.265575
# Training until validation scores don't improve for 50 rounds.
# [2]	train's spearman: 0.316225	eval's spearman: 0.265075
# [3]	train's spearman: 0.320671	eval's spearman: 0.267838
# [4]	train's spearman: 0.32503	eval's spearman: 0.270543
# [5]	train's spearman: 0.332552	eval's spearman: 0.279408
# [6]	train's spearman: 0.333219	eval's spearman: 0.279731
# [7]	train's spearman: 0.336042	eval's spearman: 0.280312
# [8]	train's spearman: 0.340067	eval's spearman: 0.28262
# [9]	train's spearman: 0.341463	eval's spearman: 0.285785
# [10]	train's spearman: 0.34205	eval's spearman: 0.285692
# [11]	train's spearman: 0.343486	eval's spearman: 0.286624
# [12]	train's spearman: 0.344188	eval's spearman: 0.286932
# [13]	train's spearman: 0.345656	eval's spearman: 0.288773
# [14]	train's spearman: 0.345619	eval's spearman: 0.288802
# [15]	train's spearman: 0.346547	eval's spearman: 0.287974
# ...

# %%
# 予測
# %%time
print(ScoringService.get_model(model_path=model_path))
print(ScoringService.predict(inputs))
# Out:
# ストリーミング出力は最後の 5000 行に切り捨てられました。
# 2020-05-08-7456,0.06873092105255797,-0.06450510321822249
# 2020-05-14-7456,0.055176070004054334,-0.07642881885086351
# 2020-08-07-7456,0.10107152926979932,-0.07165647268630258
# 2020-11-11-7456,0.07986383703110746,-0.0509914543050652
# 2020-02-07-7458,0.05411441931005586,-0.0386709801457491
# 2020-04-08-7458,0.18906453617479627,-0.036938727183264616
# 2020-05-13-7458,0.07241481372690944,-0.09481699273130975
# 2020-08-07-7458,0.08021783283669563,-0.11676448090377274
# 2020-11-09-7458,0.13230428177692982,-0.05040768251219878
# 2020-01-31-7459,0.05240101813394257,-0.03991678762511913
# 2020-04-28-7459,0.0838679906430307,-0.06331384074473109
# 2020-05-14-7459,0.056127826710147335,-0.05662243051382305
# 2020-07-31-7459,0.0360988410980305,-0.05334572782569752
# 2020-10-30-7459,0.039847454426282986,-0.07260141328862893
# 2020-01-27-7460,0.05189149210817229,-0.017825004816663576
# 2020-04-27-7460,0.06440895171767118,-0.03238969644757604
# ...

# %%
# !pip freeze > /content/drive/MyDrive/signate/SIGNATE_fundamentals_analysis/requirements_from_colab.txt
